# %% [markdown]
# <a href="https://colab.research.google.com/github/DGMiles/MSMUPChem/blob/main/maxandmin0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.constants import h #Planck's constant
from scipy.constants import c #speed of light
from scipy.constants import k #Boltzmann constant
from IPython.display import Markdown as md
#
def wavefcn(distance, n, L):
    psi = np.sin(n*3.14159*distance/L)
    return psi



#let's graph a particle in a box wavefunction
n=3.0
L=1.0       #an arbitrary length
x=np.arange(0,L,0.0001)    #set up 10000 points between 0 and L

psi1=wavefcn(x,n,L)
plt.plot(x,psi1,'ro')
plt.grid()
plt.show()


psi2=psi1**2
plt.plot(x,psi2,'bo')
plt.grid()
plt.show()
maxes = [x[i] for i in range(len(psi2)) if psi2[i]>=max(psi2)-.000001]
print("maxima=",maxes)
mins = [x[i] for i in range(len(psi2)) if psi2[i]<=min(psi2)+.000001]
print("minima(nodes)=",mins)
# Out:
# maxima= [0.1666, 0.16670000000000001, 0.4999, 0.5, 0.5001, 0.8333, 0.8334]
# minima(nodes)= [0.0, 0.0001, 0.33330000000000004, 0.33340000000000003, 0.6666000000000001, 0.6667000000000001, 0.9999]
